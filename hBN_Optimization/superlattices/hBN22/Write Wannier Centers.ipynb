# %%
supercell=2
for i in 1:(supercell^2)
    println("wannier-center N $i pz")
end
for i in 1:(supercell^2)
    println("wannier-center B $i pz")
end
for i in 0:supercell-1
    for j in 0:supercell-1
        println("wannier-center Gaussian $(1/6/supercell + i/supercell) $(1/3/supercell + j/supercell) 0")
        println("wannier-center Gaussian $(1/6/supercell + i/supercell) $(-1/6/supercell + j/supercell) 0")
        println("wannier-center Gaussian $(-1/3/supercell + i/supercell) $(-1/6/supercell + j/supercell) 0")
        println("wannier-center Gaussian $(2/3/supercell + i/supercell) $(1/3/supercell + j/supercell) 0.05")
        println("wannier-center Gaussian $(2/3/supercell + i/supercell) $(1/3/supercell + j/supercell) -0.05")
    end
end
# Out:
# wannier-center N 1 pz
# wannier-center N 2 pz
# wannier-center N 3 pz
# wannier-center N 4 pz
# wannier-center B 1 pz
# wannier-center B 2 pz
# wannier-center B 3 pz
# wannier-center B 4 pz
# wannier-center Gaussian 0.08333333333333333 0.16666666666666666 0
# wannier-center Gaussian 0.08333333333333333 -0.08333333333333333 0
# wannier-center Gaussian -0.16666666666666666 -0.08333333333333333 0
# wannier-center Gaussian 0.3333333333333333 0.16666666666666666 0.05
# wannier-center Gaussian 0.3333333333333333 0.16666666666666666 -0.05
# wannier-center Gaussian 0.08333333333333333 0.6666666666666666 0
# wannier-center Gaussian 0.08333333333333333 0.4166666666666667 0
# wannier-center Gaussian -0.16666666666666666 0.4166666666666667 0
# wannier-center Gaussian 0.3333333333333333 0.6666666666666666 0.05
# wannier-center Gaussian 0.3333333333333333 0.6666666666666666 -0.05
# wannier-center Gaussian 0.5833333333333334 0.16666666666666666 0
# wannier-center Gaussian 0.5833333333333334 -0.08333333333333333 0
# wannier-center Gaussian 0.33333333333333337 -0.08333333333333333 0
# wannier-center Gaussian 0.8333333333333333 0.16666666666666666 0.05
# wannier-center Gaussian 0.8333333333333333 0.16666666666666666 -0.05
# wannier-center Gaussian 0.5833333333333334 0.6666666666666666 0
# wannier-center Gaussian 0.5833333333333334 0.4166666666666667 0
# wannier-center Gaussian 0.33333333333333337 0.4166666666666667 0
# wannier-center Gaussian 0.8333333333333333 0.6666666666666666 0.05
# wannier-center Gaussian 0.8333333333333333 0.6666666666666666 -0.05
