# %%
using PyPlot, PyCall
np=pyimport("numpy")
# Out:
# PyObject <module 'numpy' from '/home/gridsan/aligho/.local/lib/python3.8/site-packages/numpy/__init__.py'>

# %%
function superlattice(n::Integer, io::IO)
        println("ion \${alkali} $(2/(3*n)) $(1/(3*n)) \${d} 0")
    for i in 0:(n-1)
        for j in 0:(n-1)
        println("ion B $(i/n) $(j/n) 0 0")
        println("ion N $(i/n+1/(3*n)) $(j/n+(2/(3*n))) 0 0")
        end
    end
end
# Out:
# superlattice (generic function with 2 methods)

# %%
superlattice(1)
# Out:
# ion ${alkali} 0.6666666666666666 0.3333333333333333 ${d} 0
# ion B 0.0 0.0 0 0
# ion N 0.3333333333333333 0.6666666666666666 0 0
