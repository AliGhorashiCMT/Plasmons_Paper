# %%
using Pkg
Pkg.activate("/home/gridsan/aligho/Github_Projects/JJDFTX.jl/")
ENV["JULIA_REVISE_POLL"]="1";

# %%
using Revise

# %%
using PyPlot, PyCall, Peaks, Statistics, JJDFTX;
# Out:
# Your version of python is not linked to helper_scripts.py
# Your version of python is not linked to the Atomic Simulation Environment

# %%
supercell=3
println("wannier-center C 1 pz")
for i in 1:(supercell^2)
    println("wannier-center N $i pz")
end
for i in 1:(supercell^2-1)
    println("wannier-center B $i pz")
end
for i in 0:supercell-1
    for j in 0:supercell-1
        println("wannier-center Gaussian $(1/6/supercell + i/supercell) $(1/3/supercell + j/supercell) 0")
        println("wannier-center Gaussian $(1/6/supercell + i/supercell) $(-1/6/supercell + j/supercell) 0")
        println("wannier-center Gaussian $(-1/3/supercell + i/supercell) $(-1/6/supercell + j/supercell) 0")
        println("wannier-center Gaussian $(2/3/supercell + i/supercell) $(1/3/supercell + j/supercell) 0.05")
        println("wannier-center Gaussian $(2/3/supercell + i/supercell) $(1/3/supercell + j/supercell) -0.05")
    end
end
# Out:
# wannier-center C 1 pz
# wannier-center N 1 pz
# wannier-center N 2 pz
# wannier-center N 3 pz
# wannier-center N 4 pz
# wannier-center N 5 pz
# wannier-center N 6 pz
# wannier-center N 7 pz
# wannier-center N 8 pz
# wannier-center N 9 pz
# wannier-center B 1 pz
# wannier-center B 2 pz
# wannier-center B 3 pz
# wannier-center B 4 pz
# wannier-center B 5 pz
# wannier-center B 6 pz
# wannier-center B 7 pz
# wannier-center B 8 pz
# wannier-center Gaussian 0.05555555555555555 0.1111111111111111 0
# wannier-center Gaussian 0.05555555555555555 -0.05555555555555555 0
# wannier-center Gaussian -0.1111111111111111 -0.05555555555555555 0
# wannier-center Gaussian 0.2222222222222222 0.1111111111111111 0.05
# wannier-center Gaussian 0.2222222222222222 0.1111111111111111 -0.05
# wannier-center Gaussian 0.05555555555555555 0.4444444444444444 0
# wannier-center Gaussian 0.05555555555555555 0.2777777777777778 0
# wannier-center Gaussian -0.1111111111111111 0.2777777777777778 0
# ...
