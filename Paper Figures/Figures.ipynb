# %%
using Pkg
ENV["JULIA_REVISE_POLL"]="1"
Pkg.activate("/home/gridsan/aligho/Github_Projects/JJDFTX.jl/")
using PyPlot
using JJDFTX
# Out:
# ┌ Info: Precompiling JJDFTX [0d21db8c-e7cb-497b-98f4-4306b49e2569]
# └ @ Base loading.jl:1317
# Your version of python is not linked to helper_scripts.py
# Your version of python is not linked to the Atomic Simulation Environment

# %%
HOME = ENV["HOME"]
# Out:
# "/home/gridsan/aligho"

# %%
pwd()
# Out:
# "/home2/gridsan/aligho/Plasmons/Plasmons_Paper/Paper Figures"

# %%
Moire7_dir = "../Moire_Figs/Moire7_with_Alkali"

Na7_dir = "../Moire_Figs/Moire7_with_Alkali/Sodium"
Rb13_dir = "../Moire_Figs/Moire7_with_Alkali/Rubidium"
Rb7_dir = "../Moire_Figs/Moire7_with_Alkali/Rubidium"
Na13_dir = "../Moire_Figs/Moire13_with_Alkali/Sodium"
# Out:
# "../Moire_Figs/Moire13_with_Alkali/Sodium"

# %%
figure(figsize=(10, 10))
subplot(3, 3, 1)
ylim(-10, 0)
plot_bands(Na7_dir*"/Na-bands-0.358.eigenvals", kpointsfile = Na7_dir*"/bandstruct.kpoints", spin=2, kticksfile=Moire7_dir*"/bandstruct.kpoints.in",  to_greek=true)
subplot(3, 3, 2)
ylim(-10, 0)
plot_bands(Na13_dir*"/Na-bands-0.358.eigenvals", kpointsfile = Na13_dir*"/bandstruct.kpoints", spin=2, kticksfile=Moire7_dir*"/bandstruct.kpoints.in",  to_greek=true)
subplot(3, 3, 3)
ylim(-10, 0)
plot_bands(Rb13_dir*"/Rb-bands-0.358.eigenvals", kpointsfile = Rb13_dir*"/bandstruct.kpoints", spin=2, kticksfile=Moire7_dir*"/bandstruct.kpoints.in",  to_greek=true)
subplot(3, 3, 4)
plot_bands(Rb7_dir*"/Rb-bands-0.358.eigenvals", kpointsfile = Rb7_dir*"/bandstruct.kpoints", spin=2, kticksfile=Moire7_dir*"/bandstruct.kpoints.in",  to_greek=true)

ylim(-10, 0)
# Out:
# Figure(PyObject <Figure size 1000x1000 with 4 Axes>)
# (-10.0, 0.0)

# %%
figure(figsize=(10, 10))
subplot(2, 3, 1)
subplot(2, 3, 2)
subplot(2, 3, 3)
subplot(2, 3, 4)
subplot(2, 3, 5)
subplot(2, 3, 6)
# Out:
# Figure(PyObject <Figure size 1000x1000 with 6 Axes>)
# PyObject <AxesSubplot:>

# %%
figure(figsize=(10, 10))
# Out:
# Figure(PyObject <Figure size 1000x1000 with 0 Axes>)
