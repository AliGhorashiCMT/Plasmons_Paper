# %%
using Pkg
Pkg.activate("/home/gridsan/aligho/Github_Projects/JJDFTX.jl/")

# %%
ENV["JULIA_REVISE_POLL"]="1";

# %%
using Revise

# %%
using PyPlot, PyCall, Peaks, JJDFTX;

# %%
na_dir="./Sodium"
li_dir="./Lithium"
k_dir="./Potassium"
rb_dir="./Rubidium"
cs_dir="./Cesium"
# Out:
# "./Cesium"

# %%
figure(figsize=(15, 10))
subplot(2, 2, 1)
plot_bands("$na_dir/Na-2-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Na 2x2 Bands")
subplot(2, 2, 2)
plot_bands("$na_dir/Na-3-bands.eigenvals", spin=2, to_greek=true)
ylim(-4, 2)
xlim(0, 163)
title("Na 3x3 Bands")
subplot(2, 2, 3)
plot_bands("$na_dir/Na-4-bands.eigenvals", spin=2, to_greek=true)
ylim(-4, 2)
xlim(0, 163)
title("Na 4x4 Bands")
# Out:
# Figure(PyObject <Figure size 1500x1000 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Na 4x4 Bands')

# %%
figure(figsize=(15, 10))
subplot(2, 2, 1)
plot_bands("$li_dir/Li-2-bands.eigenvals", spin=2, to_greek=true)
title("Li 2x2 Bands")
ylim(-5, 3)
subplot(2, 2, 2)
plot_bands("$li_dir/Li-3-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Li 3x3 Bands")
subplot(2, 2, 3)
plot_bands("$li_dir/Li-4-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Li 4x4 Bands")
# Out:
# Figure(PyObject <Figure size 1500x1000 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Li 4x4 Bands')

# %%
figure(figsize=(15, 10))
subplot(2, 2, 1)
plot_bands("$k_dir/K-2-bands.eigenvals", spin=2, to_greek=true)
title("K 2x2 Bands")
ylim(-5, 3)
subplot(2, 2, 2)
plot_bands("$k_dir/K-3-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("K 3x3 Bands")
subplot(2, 2, 3)
plot_bands("$k_dir/K-4-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("K 4x4 Bands")
# Out:
# Figure(PyObject <Figure size 1500x1000 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'K 4x4 Bands')

# %%
figure(figsize=(15, 10))
subplot(2, 2, 1)
plot_bands("$rb_dir/Rb-2-bands.eigenvals", spin=2, to_greek=true)
title("Rb 2x2 Bands")
ylim(-5, 3)
subplot(2, 2, 2)
plot_bands("$rb_dir/Rb-3-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Rb 3x3 Bands")
subplot(2, 2, 3)
plot_bands("$rb_dir/Rb-4-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Rb 4x4 Bands")
# Out:
# Figure(PyObject <Figure size 1500x1000 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Rb 4x4 Bands')

# %%
figure(figsize=(15, 10))
subplot(2, 2, 1)
plot_bands("$cs_dir/Cs-2-bands.eigenvals", spin=2, to_greek=true)
title("Cs 2x2 Bands")
ylim(-5, 3)
subplot(2, 2, 2)
plot_bands("$cs_dir/Cs-3-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Cs 3x3 Bands")
subplot(2, 2, 3)
plot_bands("$cs_dir/Cs-4-bands.eigenvals", spin=2, to_greek=true)
ylim(-5, 2)
xlim(0, 163)
title("Cs 4x4 Bands")
# Out:
# Figure(PyObject <Figure size 1500x1000 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Cs 4x4 Bands')
